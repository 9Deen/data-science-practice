# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/DataScience/Datasets/student.csv')

df
# Out:
#    Studentid  FirstName  LastName
# 0  664231001        Ney       Pet
# 1  664234014        Ter       San
# 2  664234030          Q       Jit
