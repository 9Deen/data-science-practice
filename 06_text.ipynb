# %%
# !pip install deepcut
# Out:
# Collecting deepcut
#   Downloading deepcut-0.7.0.0-py3-none-any.whl.metadata (600 bytes)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepcut) (2.19.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from deepcut) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from deepcut) (1.16.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deepcut) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from deepcut) (1.6.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from deepcut) (3.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (3.10.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->deepcut) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->deepcut) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->deepcut) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->deepcut) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->deepcut) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->deepcut) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->deepcut) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->deepcut) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->deepcut) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->deepcut) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->deepcut) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->deepcut) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->deepcut) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->deepcut) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->deepcut) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->deepcut) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->deepcut) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.0.0->deepcut) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->deepcut) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->deepcut) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.0.0->deepcut) (0.1.2)
# Downloading deepcut-0.7.0.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.0 MB/s eta 0:00:00
# Installing collected packages: deepcut
# Successfully installed deepcut-0.7.0.0

# %%
import deepcut
deepcut.tokenize('จะออกไปแตะขอบฟ้า แต่เหมือนว่าโชคชะตาไม่เข้าใจ')
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ['จะ',
#  'ออก',
#  'ไป',
#  'แตะ',
#  'ขอบ',
#  'ฟ้า',
#  ' ',
#  'แต่',
#  'เหมือน',
#  'ว่า',
#  'โชคชะตา',
#  'ไม่',
#  'เข้าใจ']

# %%
# !pip install attacut
# Out:
# Collecting attacut
#   Downloading attacut-1.0.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting docopt>=0.6.2 (from attacut)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fire>=0.1.3 (from attacut)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting nptyping>=0.2.0 (from attacut)
#   Downloading nptyping-2.5.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from attacut) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1.2 in /usr/local/lib/python3.12/dist-packages (from attacut) (6.0.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from attacut) (1.17.0)
# Collecting ssg>=0.0.4 (from attacut)
#   Downloading ssg-0.0.8-py3-none-any.whl.metadata (762 bytes)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from attacut) (2.8.0+cu126)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire>=0.1.3->attacut) (3.1.0)
# Collecting numpy>=1.17.0 (from attacut)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.1 MB/s eta 0:00:00
# Collecting python-crfsuite>=0.9.6 (from ssg>=0.0.4->attacut)
#   Downloading python_crfsuite-0.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.12/dist-packages (from ssg>=0.0.4->attacut) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->attacut) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.2.0->attacut) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.2.0->attacut) (3.0.3)
# Downloading attacut-1.0.6-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.4 MB/s eta 0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 10.2 MB/s eta 0:00:00
# Downloading nptyping-2.5.0-py3-none-any.whl (37 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 102.8 MB/s eta 0:00:00
# Downloading ssg-0.0.8-py3-none-any.whl (473 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 39.4 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.8 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=0fac2951ba7db3c0c26c461e2eb64950995189653cd718c87b7268c2833ab50f
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, python-crfsuite, numpy, fire, ssg, nptyping, attacut
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed attacut-1.0.6 docopt-0.6.2 fire-0.7.1 nptyping-2.5.0 numpy-1.26.4 python-crfsuite-0.9.11 ssg-0.0.8

# %%
from attacut import tokenize, Tokenizer

text = "จะออกไปแตะขอบฟ้า แต่เหมือนว่าโชคชะตาไม่เข้าใจ"

# tokenize using our best model `attacut-sc`
words = tokenize(text)

words
# Out:
# ['จะ',
#  'ออก',
#  'ไป',
#  'แตะ',
#  'ขอบ',
#  'ฟ้า',
#  ' ',
#  'แต่',
#  'เหมือน',
#  'ว่า',
#  'โชคชะตา',
#  'ไม่',
#  'เข้าใจ']

# %%
# !pip install OSKut
# !pip install sefr_cut
# Out:
# Collecting OSKut
#   Downloading OSKut-1.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from OSKut) (2.19.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from OSKut) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from OSKut) (1.16.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from OSKut) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from OSKut) (1.6.1)
# Collecting pyahocorasick<=1.4.0 (from OSKut)
#   Downloading pyahocorasick-1.4.0.tar.gz (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.1/312.1 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->OSKut) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->OSKut) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->OSKut) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->OSKut) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->OSKut) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->OSKut) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->OSKut) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->OSKut) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->OSKut) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->OSKut) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->OSKut) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->OSKut) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->OSKut) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->OSKut) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->OSKut) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->OSKut) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->OSKut) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.0.0->OSKut) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->OSKut) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->OSKut) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.0.0->OSKut) (0.1.2)
# Downloading OSKut-1.3-py3-none-any.whl (44.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 17.4 MB/s eta 0:00:00
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.0-cp312-cp312-linux_x86_64.whl size=93245 sha256=c5048e188de061e9636111b0c8114e0368dc9080ff306189e28ec49930525672
#   Stored in directory: /root/.cache/pip/wheels/6f/07/7b/4e0be2971f7b0873a6f843902241f6de59bc65da4f0b8f8fb8
# Successfully built pyahocorasick
# Installing collected packages: pyahocorasick, OSKut
# Successfully installed OSKut-1.3 pyahocorasick-1.4.0
# Collecting sefr_cut
#   Downloading SEFR_CUT-1.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (2.19.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (1.16.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (1.6.1)
# Requirement already satisfied: python-crfsuite in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (0.9.11)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.12/dist-packages (from sefr_cut) (1.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.0.0->sefr_cut) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->sefr_cut) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->sefr_cut) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->sefr_cut) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sefr_cut) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sefr_cut) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->sefr_cut) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->sefr_cut) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->sefr_cut) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->sefr_cut) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->sefr_cut) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->sefr_cut) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->sefr_cut) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0->sefr_cut) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->sefr_cut) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->sefr_cut) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.0.0->sefr_cut) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.0.0->sefr_cut) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->sefr_cut) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->sefr_cut) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.0.0->sefr_cut) (0.1.2)
# Downloading SEFR_CUT-1.1-py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 66.9 MB/s eta 0:00:00
# Installing collected packages: sefr_cut
# Successfully installed sefr_cut-1.1

# %%
import oskut
oskut.load_model(engine='ws')
print(oskut.OSKut('สวัสดีประเทศไทย'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ['สวัสดี', 'ประเทศ', 'ไทย']

# %%
# !pip install pythainlp
# Out:
# Collecting pythainlp
#   Downloading pythainlp-5.1.2-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from pythainlp) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->pythainlp) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->pythainlp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->pythainlp) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->pythainlp) (2025.8.3)
# Downloading pythainlp-5.1.2-py3-none-any.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 64.9 MB/s eta 0:00:00
# Installing collected packages: pythainlp
# Successfully installed pythainlp-5.1.2

# %%
from pythainlp.tokenize import word_tokenize
text = "จะออกไปแตะขอบฟ้า แต่เหมือนว่าโชคชะตาไม่เข้าใจ"

# %%
words=word_tokenize(text, engine="longest")
print(words)
print('')
# Out:
# ['จะ', 'ออก', 'ไป', 'แตะ', 'ขอบฟ้า', ' ', 'แต่', 'เหมือนว่า', 'โชคชะตา', 'ไม่', 'เข้าใจ']

# %%
words=word_tokenize(text, engine="mm")
print(words)
print('')
# Out:
# ['จะ', 'ออก', 'ไป', 'แตะ', 'ขอบฟ้า', ' ', 'แต่', 'เหมือนว่า', 'โชคชะตา', 'ไม่', 'เข้าใจ']

# %%
from pythainlp.tag import pos_tag, pos_tag_sents

text = "จะออกไปแตะขอบฟ้า แต่เหมือนว่าโชคชะตาไม่เข้าใจ"

words=word_tokenize(text, engine="longest")

pos_tag(words, corpus='pud')
# Out:
# [('จะ', 'AUX'),
#  ('ออก', 'VERB'),
#  ('ไป', 'PART'),
#  ('แตะ', 'VERB'),
#  ('ขอบฟ้า', 'NOUN'),
#  (' ', 'NOUN'),
#  ('แต่', 'CCONJ'),
#  ('เหมือนว่า', 'ADP'),
#  ('โชคชะตา', 'NOUN'),
#  ('ไม่', 'PART'),
#  ('เข้าใจ', 'VERB')]

# %%
#ref: https://github.com/JagerV3/sentiment_analysis_thai

import pandas as pd
df=pd.read_csv('burgerking-UTF8-traindataset-3.csv')
df=df.rename(columns={'class':'class_label','message':'text'})
df
# Out:
#     class_label                                               text
# 0             0  11.30 น. ไปที่สาขาในปั๊มคาลเท็กซ์ ประชานุกูล ซ...
# 1             0  BK ทุกสาขาบริการดี โดยเฉพาะอย่างยิ่งเอมโพเรียม...
# 2             0  Burger King สาขา The Bright พระราม 2 บริการห่ว...
# 3             0  Burger King สาขาปั้ม ป.ต.ท.บ้านพร อ.ถลาง \rเมื...
# 4             0  chicken strip ชิ้นเล็กมาก เทียบกับป้ายโฆษณาบนโต๊ะ
# ..          ...                                                ...
# 67            1  ถ้าเทียบกับร้านลักษณะแบบเดียวกันอย่าง K. หรือ ...
# 68            1                ทานบ่อยมากค่ะ รสชาติอร่อยทีเดียวเลย
# 69            1                                  น่ากินทุกอย่างเลย
# 70            1                                  น่าทานอร่อยดีครับ
# 71            1                                 น่ารับประทานมากเลย
#
# [72 rows x 2 columns]

# %%
import re
import string
from pythainlp.corpus.common import thai_stopwords
from pythainlp.tokenize import word_tokenize

thai_stopwords = list(thai_stopwords())
thai_stopwords

def perform_removal(word):
    #กำจัดช่องว่างก่อน/หลังคำ
    word = word.strip()

    #เปลี่ยนภาษาอังกฤษเป็นตัวอักษรตัวเล็ก
    word = word.lower()

    #กำจัดเครื่องหมายวรรคตอน
    word = word.translate(str.maketrans('','', string.punctuation))

    #กำจัด stop words และตัวเลขโดดๆ
    if(word.isdigit() ):
        return ""
    else:
        return word

def clean_text(text):
  text = "".join(u for u in text if u not in ("?", ".", ";", ":", "!", '"', "ๆ", "ฯ","'"))
  tokens=word_tokenize(text, engine="oskut", keep_whitespace=False)

  tokens = [word for word in tokens if word.lower not in thai_stopwords]

  tokens = [word for word in tokens if len(word)>1]

  tokens = [perform_removal(word) for word in tokens]


  text = ' '.join(tokens)
  return text

# %%
df['text'] = df['text'].apply(lambda x:clean_text(x))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c848c44fd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

df_pos = df[df['class_label'] == 1]
pos_word_all = " ".join(text for text in df_pos['text'])
reg = r"[ก-๙a-zA-Z']+"
fp = 'THSarabunNew.ttf'
wordcloud = WordCloud(stopwords=thai_stopwords, background_color = 'white', max_words=2000, height = 2000, width=4000, font_path=fp, regexp=reg).generate(pos_word_all)
plt.figure(figsize = (16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
df_neg = df[df['class_label'] == 0]
neg_word_all = " ".join(text for text in df_neg['text'])
wordcloud = WordCloud(stopwords=thai_stopwords, background_color = 'white', max_words=2000, height = 2000, width=4000, font_path=fp, regexp=reg).generate(neg_word_all)
plt.figure(figsize = (16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.20, stratify=df['class_label'])

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

def identity_fun(text):
    return text.split()


# CountVectorizer
vec = CountVectorizer(
    analyzer = 'word', #this is default
    tokenizer=identity_fun, #does no extra tokenizing
    ngram_range=(1,3),
    max_features=300
)


'''
#TFIDF
vec = TfidfVectorizer(
    analyzer = 'word', #this is default
    tokenizer=identity_fun, #does no extra tokenizing
    ngram_range=(1,3),
    max_features=300
)
'''


vec.fit(df_train['text'])
vec.vocabulary_
# Out:
# {'ผิด': 124,
#  'หวัง': 199,
#  'ครับ': 25,
#  'กับ': 9,
#  'รสชาติ': 155,
#  'ชิ้น': 57,
#  'ละ': 165,
#  'สอง': 175,
#  'วอปเปอร์': 169,
#  'ผิด หวัง': 125,
#  'ทาน': 82,
#  'บ่อย': 115,
#  'มาก': 145,
#  'ค่ะ': 43,
#  'ที': 86,
#  'เดียว': 225,
#  'เลย': 239,
#  'มาก ค่ะ': 147,
#  'วัน': 170,
#  'ที่': 87,
#  'จน': 46,
#  'นี้': 104,
#  'ยัง': 152,
#  'ไม่': 294,
#  'ได้': 286,
#  'จริง': 47,
#  'ถ้า': 76,
#  'จะ': 48,
#  'ดู': 64,
#  'วัน ที่': 171,
#  'วัน นี้': 172,
#  'ยัง ไม่': 153,
#  'ไม่ ได้': 298,
#  'ถ้า ไม่': 77,
#  'ร้าน': 163,
#  'แบบ': 260,
#  'กัน': 8,
#  'อย่าง': 207,
#  'หรือ': 198,
#  'burger': 2,
#  'king': 5,
#  'ก็': 12,
#  'กิน': 11,
#  'ขาด': 22,
#  'สาขา': 178,
#  'น้อย': 106,
#  'ไป': 287,
#  'หน่อย': 195,
#  'แต่': 258,
#  'ขยาย': 16,
#  'ดีใจ': 61,
#  'มา': 143,
#  'เปิด': 231,
#  'burger king': 3,
#  'สาขา น้อย': 181,
#  'ไป หน่อย': 292,
#  'ขยาย สาขา': 17,
#  'ดีใจ ที่': 62,
#  'ที่ มา': 90,
#  'ดีใจ ที่ มา': 63,
#  'สา': 177,
#  'ขา': 21,
#  'สนาม': 174,
#  'คือ': 38,
#  'อาหาร': 213,
#  'ราคา': 159,
#  'อยู่': 206,
#  'แล้ว': 273,
#  'มี': 151,
#  'พนัก': 133,
#  'งาน': 45,
#  'รับ': 157,
#  'ออเดอร์': 211,
#  'แค่': 254,
#  'คน': 24,
#  'ทำ': 83,
#  'ให้': 284,
#  'รอ': 156,
#  'สั่ง': 176,
#  'นาน': 101,
#  'และ': 267,
#  'เหมือน': 248,
#  'พอ': 139,
#  'เย็น': 237,
#  'ความ': 29,
#  'อร่อย': 208,
#  'พนักงาน': 136,
#  'รู้': 160,
#  'แก้': 252,
#  'ปรับ': 119,
#  'ปรุง': 121,
#  'ด้วย': 65,
#  'นะ': 96,
#  'คะ': 30,
#  'พนัก งาน': 134,
#  'รับ ออเดอร์': 158,
#  'ทำ ให้': 84,
#  'นาน มาก': 102,
#  'อาหาร ที่': 214,
#  'และ ไม่': 272,
#  'ไม่ มี': 296,
#  'ปรับ ปรุง': 120,
#  'ด้วย นะ': 66,
#  'นะ คะ': 97,
#  'พนัก งาน รับ': 135,
#  'หา': 202,
#  'ดี': 59,
#  'สุด': 191,
#  'ทำไม': 85,
#  'ที่ สุด': 92,
#  'หัว': 200,
#  'ใช้': 280,
#  'บริการ': 108,
#  'หน้า': 196,
#  'ลูก': 166,
#  'ค้า': 44,
#  'ต่อ': 71,
#  'คิว': 36,
#  'เป็น': 232,
#  'น้ำ': 107,
#  'เสียง': 247,
#  'พูด': 140,
#  'คำ': 33,
#  'ลูกค้า': 168,
#  'เบอร์เกอร์': 228,
#  'สีหน้า': 188,
#  'บอก': 112,
#  'ผู้': 126,
#  'กลับ': 6,
#  'ทั้ง': 79,
#  'ชม': 53,
#  'ใจ': 278,
#  'โดน': 276,
#  'เสีย': 245,
#  'ใส่': 282,
#  'ใน': 281,
#  'จัด': 50,
#  'ค่อย': 42,
#  'การ': 10,
#  'ลูก ค้า': 167,
#  'นัก งาน': 98,
#  'เลย ค่ะ': 240,
#  'หัว หน้า': 201,
#  'ที่ จะ': 88,
#  'พนักงาน ทำ': 137,
#  'ทั้ง ที่': 80,
#  'ที่ จัด': 89,
#  'อาหาร ให้': 216,
#  'ชอบ': 54,
#  'สำ': 183,
#  'คุณ': 39,
#  'ภาพ': 141,
#  'ของ': 20,
#  'อยาก': 204,
#  'แถว': 259,
#  'เกล้า': 220,
#  'บ้าง': 116,
#  'ชอบ มาก': 55,
#  'คุณ ภาพ': 40,
#  'และ รสชาติ': 270,
#  'อยาก ให้': 205,
#  'สาขา แถว': 182,
#  'สำ หรับ คุณ': 184,
#  'และ รสชาติ ของ': 271,
#  'แย่': 263,
#  'ยืน': 154,
#  'ต่าง': 72,
#  'แซง': 256,
#  'ก่อน': 15,
#  'ว่า': 173,
#  'เรา': 238,
#  'ขอ': 18,
#  'บริการ แย่': 110,
#  'แย่ มาก': 264,
#  'แซง คิว': 257,
#  'คะ ว่า': 31,
#  'แบบ นี้': 261,
#  'บริการ แย่ มาก': 111,
#  'แจ้ง': 255,
#  'ผ่าน': 130,
#  'ทาง': 81,
#  'บ้าน': 117,
#  'เนื้อ': 227,
#  'อัน': 212,
#  'เก่า': 221,
#  'อร่อย มาก': 209,
#  'มาก แต่': 150,
#  'bk': 1,
#  'ทุก': 95,
#  'เยอะ': 236,
#  'คุณภาพ': 41,
#  'เซ็นทรัลเวิลด์': 224,
#  'ต่ำ': 73,
#  'ไว้': 299,
#  'ครั้ง': 26,
#  'รู้สึก': 162,
#  'มัน': 142,
#  'เอา': 250,
#  'เปลี่ยน': 230,
#  'ตอน': 67,
#  'คิด': 35,
#  'คง': 23,
#  'อีก': 218,
#  'เขา': 222,
#  'อื่น': 219,
#  'ถึง': 75,
#  'เลือก': 242,
#  'สึก': 189,
#  'พนง': 132,
#  'บริการ ดี': 109,
#  'และ คุณภาพ': 268,
#  'ดี มาก': 60,
#  'มาก ที่': 149,
#  'ที่ สาขา': 91,
#  'สาขา ที่': 179,
#  'มาก ทั้ง': 148,
#  'พนักงาน บริการ': 138,
#  'เอา ไป': 251,
#  'ไป ทาน': 290,
#  'ก็ ยัง': 13,
#  'สาขา นี้': 180,
#  'เสีย ความ': 246,
#  'รู้ สึก': 161,
#  'สึก มาก': 190,
#  'และ คุณภาพ อาหาร': 269,
#  'คิง': 34,
#  'เวลา': 243,
#  'ประมาณ': 118,
#  'ครึ่ง': 28,
#  'ผู้หญิง': 129,
#  'เข้า': 223,
#  'ฝรั่ง': 131,
#  'ปิด': 122,
#  'นี่': 103,
#  'จำ': 52,
#  'เหรอ': 249,
#  'อาหาร ใน': 215,
#  'ห่วย': 203,
#  'อิน': 217,
#  'ทราบ': 78,
#  'ออก': 210,
#  'กว่า': 7,
#  'เฟรนฟราย': 234,
#  'หมด': 197,
#  'บอกว่า': 113,
#  'เดี๋ยว': 226,
#  'โต๊ะ': 277,
#  'นั่ง': 99,
#  'ใหญ่': 283,
#  'ตาม': 70,
#  'เสริฟ': 244,
#  'ชุด': 58,
#  'ต้อง': 74,
#  'ใช่': 279,
#  'สุด วัน': 192,
#  'แล้ว เฟรนฟราย': 275,
#  'ที่ โต๊ะ': 93,
#  'ก็ ไม่': 14,
#  'ไป นั่ง': 291,
#  'นั่ง รอ': 100,
#  'ไม่ มา': 295,
#  'แล้ว ก็': 274,
#  'ไป ตาม': 289,
#  'ครั้ง ที่': 27,
#  'ไป เสริฟ': 293,
#  'ผู้ จัด': 127,
#  'จัด การ': 51,
#  'จะ ไป': 49,
#  'สุด แต่': 194,
#  'สุด วัน นี้': 193,
#  'ผู้ จัด การ': 128,
#  'น่า': 105,
#  'มาก ครับ': 146,
#  'ชอบ มาก ครับ': 56,
#  'bbq': 0,
#  'chicken': 4,
#  'ตั้ง': 68,
#  'ลง': 164,
#  'ตั้ง แต่': 69,
#  'แย่ ลง': 265,
#  'คืน': 37,
#  'ผม': 123,
#  'บาง': 114,
#  'แรก': 266,
#  'แผ่น': 262,
#  'เลี่ยน': 241,
#  'เมื่อ': 235,
#  'มา กิน': 144,
#  'ขอ ให้': 19,
#  'ที่ ไม่': 94,
#  'ไม่ ให้': 297,
#  'แก้ว': 253,
#  'ไป กิน': 288,
#  'เบอร์เกอร์ ที่': 229,
#  'ไก่': 285,
#  'สิน': 185,
#  'เพราะ': 233,
#  'สิน ค้า': 186,
#  'คับ': 32,
#  'สินค้า': 187}

# %%
vec.get_feature_names_out()
# Out:
# array(['bbq', 'bk', 'burger', 'burger king', 'chicken', 'king', 'กลับ',
#        'กว่า', 'กัน', 'กับ', 'การ', 'กิน', 'ก็', 'ก็ ยัง', 'ก็ ไม่',
#        'ก่อน', 'ขยาย', 'ขยาย สาขา', 'ขอ', 'ขอ ให้', 'ของ', 'ขา', 'ขาด',
#        'คง', 'คน', 'ครับ', 'ครั้ง', 'ครั้ง ที่', 'ครึ่ง', 'ความ', 'คะ',
#        'คะ ว่า', 'คับ', 'คำ', 'คิง', 'คิด', 'คิว', 'คืน', 'คือ', 'คุณ',
#        'คุณ ภาพ', 'คุณภาพ', 'ค่อย', 'ค่ะ', 'ค้า', 'งาน', 'จน', 'จริง',
#        'จะ', 'จะ ไป', 'จัด', 'จัด การ', 'จำ', 'ชม', 'ชอบ', 'ชอบ มาก',
#        'ชอบ มาก ครับ', 'ชิ้น', 'ชุด', 'ดี', 'ดี มาก', 'ดีใจ', 'ดีใจ ที่',
#        'ดีใจ ที่ มา', 'ดู', 'ด้วย', 'ด้วย นะ', 'ตอน', 'ตั้ง', 'ตั้ง แต่',
#        'ตาม', 'ต่อ', 'ต่าง', 'ต่ำ', 'ต้อง', 'ถึง', 'ถ้า', 'ถ้า ไม่',
#        'ทราบ', 'ทั้ง', 'ทั้ง ที่', 'ทาง', 'ทาน', 'ทำ', 'ทำ ให้', 'ทำไม',
#        'ที', 'ที่', 'ที่ จะ', 'ที่ จัด', 'ที่ มา', 'ที่ สาขา', 'ที่ สุด',
#        'ที่ โต๊ะ', 'ที่ ไม่', 'ทุก', 'นะ', 'นะ คะ', 'นัก งาน', 'นั่ง',
#        'นั่ง รอ', 'นาน', 'นาน มาก', 'นี่', 'นี้', 'น่า', 'น้อย', 'น้ำ',
#        'บริการ', 'บริการ ดี', 'บริการ แย่', 'บริการ แย่ มาก', 'บอก',
#        'บอกว่า', 'บาง', 'บ่อย', 'บ้าง', 'บ้าน', 'ประมาณ', 'ปรับ',
#        'ปรับ ปรุง', 'ปรุง', 'ปิด', 'ผม', 'ผิด', 'ผิด หวัง', 'ผู้',
#        'ผู้ จัด', 'ผู้ จัด การ', 'ผู้หญิง', 'ผ่าน', 'ฝรั่ง', 'พนง',
#        'พนัก', 'พนัก งาน', 'พนัก งาน รับ', 'พนักงาน', 'พนักงาน ทำ',
#        'พนักงาน บริการ', 'พอ', 'พูด', 'ภาพ', 'มัน', 'มา', 'มา กิน', 'มาก',
#        'มาก ครับ', 'มาก ค่ะ', 'มาก ทั้ง', 'มาก ที่', 'มาก แต่', 'มี',
#        'ยัง', 'ยัง ไม่', 'ยืน', 'รสชาติ', 'รอ', 'รับ', 'รับ ออเดอร์',
#        'ราคา', 'รู้', 'รู้ สึก', 'รู้สึก', 'ร้าน', 'ลง', 'ละ', 'ลูก',
#        'ลูก ค้า', 'ลูกค้า', 'วอปเปอร์', 'วัน', 'วัน ที่', 'วัน นี้',
#        'ว่า', 'สนาม', 'สอง', 'สั่ง', 'สา', 'สาขา', 'สาขา ที่', 'สาขา นี้',
#        'สาขา น้อย', 'สาขา แถว', 'สำ', 'สำ หรับ คุณ', 'สิน', 'สิน ค้า',
#        'สินค้า', 'สีหน้า', 'สึก', 'สึก มาก', 'สุด', 'สุด วัน',
#        'สุด วัน นี้', 'สุด แต่', 'หน่อย', 'หน้า', 'หมด', 'หรือ', 'หวัง',
#        'หัว', 'หัว หน้า', 'หา', 'ห่วย', 'อยาก', 'อยาก ให้', 'อยู่',
#        'อย่าง', 'อร่อย', 'อร่อย มาก', 'ออก', 'ออเดอร์', 'อัน', 'อาหาร',
#        'อาหาร ที่', 'อาหาร ใน', 'อาหาร ให้', 'อิน', 'อีก', 'อื่น',
#        'เกล้า', 'เก่า', 'เขา', 'เข้า', 'เซ็นทรัลเวิลด์', 'เดียว',
#        'เดี๋ยว', 'เนื้อ', 'เบอร์เกอร์', 'เบอร์เกอร์ ที่', 'เปลี่ยน',
#        'เปิด', 'เป็น', 'เพราะ', 'เฟรนฟราย', 'เมื่อ', 'เยอะ', 'เย็น',
#        'เรา', 'เลย', 'เลย ค่ะ', 'เลี่ยน', 'เลือก', 'เวลา', 'เสริฟ',
#        'เสีย', 'เสีย ความ', 'เสียง', 'เหมือน', 'เหรอ', 'เอา', 'เอา ไป',
#        'แก้', 'แก้ว', 'แค่', 'แจ้ง', 'แซง', 'แซง คิว', 'แต่', 'แถว',
#        'แบบ', 'แบบ นี้', 'แผ่น', 'แย่', 'แย่ มาก', 'แย่ ลง', 'แรก', 'และ',
#        'และ คุณภาพ', 'และ คุณภาพ อาหาร', 'และ รสชาติ', 'และ รสชาติ ของ',
#        'และ ไม่', 'แล้ว', 'แล้ว ก็', 'แล้ว เฟรนฟราย', 'โดน', 'โต๊ะ', 'ใจ',
#        'ใช่', 'ใช้', 'ใน', 'ใส่', 'ใหญ่', 'ให้', 'ไก่', 'ได้', 'ไป',
#        'ไป กิน', 'ไป ตาม', 'ไป ทาน', 'ไป นั่ง', 'ไป หน่อย', 'ไป เสริฟ',
#        'ไม่', 'ไม่ มา', 'ไม่ มี', 'ไม่ ให้', 'ไม่ ได้', 'ไว้'],
#       dtype=object)

# %%
import numpy as np

#สุ่มช่วงของ 5 เอกสารที่ติดกันมาทดลองใช้งาน
count_vector= vec.transform(df_train['text'][:10])
count_array = np.array(count_vector.todense())

#แปลงเป็น DataFrame เพื่อง่ายแก่การอ่าน
df_x = pd.DataFrame(count_array,columns=vec.get_feature_names_out())
df_x
# Out:
#    bbq   bk    burger  burger king  chicken      king      กลับ  กว่า  \
# 0  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
# 1  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
# 2  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
# 3  0.0  0.0  0.154277     0.166760      0.0  0.160171  0.000000   0.0
# 4  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
# 5  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
# 6  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
# 7  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.054661   0.0
# 8  0.0  0.0  0.173139     0.187148      0.0  0.179754  0.000000   0.0
# 9  0.0  0.0  0.000000     0.000000      0.0  0.000000  0.000000   0.0
#
#         กัน       กับ  ...  ไป ทาน  ไป นั่ง  ไป หน่อย  ไป เสริฟ       ไม่  \
# 0  0.000000  0.251842  ...     0.0      0.0  0.000000       0.0  0.000000
# 1  0.000000  0.000000  ...     0.0      0.0  0.000000       0.0  0.000000
# 2  0.000000  0.000000  ...     0.0      0.0  0.000000       0.0  0.190702
# 3  0.182853  0.148945  ...     0.0      0.0  0.205535       0.0  0.000000
# 4  0.101446  0.165268  ...     0.0      0.0  0.000000       0.0  0.167811
# 5  0.000000  0.000000  ...     0.0      0.0  0.000000       0.0  0.214414
# 6  0.000000  0.000000  ...     0.0      0.0  0.000000       0.0  0.000000
# 7  0.051773  0.210862  ...     0.0      0.0  0.000000       0.0  0.228381
# 8  0.000000  0.000000  ...     0.0      0.0  0.000000       0.0  0.000000
# 9  0.000000  0.000000  ...     0.0      0.0  0.000000       0.0  0.056106
#
#    ไม่ มา    ไม่ มี  ไม่ ให้   ไม่ ได้  ไว้
# 0     0.0  0.000000      0.0  0.000000  0.0
# 1     0.0  0.000000      0.0  0.000000  0.0
# 2     0.0  0.000000      0.0  0.345851  0.0
# 3     0.0  0.000000      0.0  0.000000  0.0
# 4     0.0  0.085592      0.0  0.000000  0.0
# 5     0.0  0.000000      0.0  0.000000  0.0
# 6     0.0  0.000000      0.0  0.000000  0.0
# 7     0.0  0.043682      0.0  0.000000  0.0
# 8     0.0  0.000000      0.0  0.000000  0.0
# 9     0.0  0.000000      0.0  0.000000  0.0
#
# [10 rows x 300 columns]

# %%
X_train = vec.transform(df_train.text)
X_test = vec.transform(df_test.text)

y_train = df_train['class_label']
y_test = df_test['class_label']

# %%
'''
# Transform (TF-IDF)
from sklearn.feature_selection import SelectKBest, mutual_info_classif

tfidf_train=vec.fit_transform(df_train.text)
tfidf_train = pd.DataFrame(np.array(tfidf_train.todense()),columns=vec.get_feature_names_out())

y_train = df_train['class_label']
y_test = df_test['class_label']

# Feature Selection
selector = SelectKBest(score_func=mutual_info_classif, k=200)
X_new = selector.fit_transform(tfidf_train, df_train.class_label)
X_train = pd.DataFrame(X_new,columns=selector.get_feature_names_out())

tfidf_test=vec.transform(df_test.text)
tfidf_test = pd.DataFrame(np.array(tfidf_test.todense()),columns=vec.get_feature_names_out())
X_test = selector.fit_transform(tfidf_test, df_test.class_label)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, classification_report

dt=DecisionTreeClassifier()
dt.fit(X_train, y_train)

preds = dt.predict(X_test)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.75      0.75      0.75         8
#
#     accuracy                           0.73        15
#    macro avg       0.73      0.73      0.73        15
# weighted avg       0.73      0.73      0.73        15

# %%
from sklearn.tree import export_graphviz
import graphviz

# Export decision tree to graphviz format
dot_data = export_graphviz(dt, out_file=None,
                           feature_names = vec.get_feature_names_out(),
                           class_names=['Neg','Pos'],
                           filled=True, rounded=True,
                           special_characters=True)

# Visualize decision tree using graphviz
graph = graphviz.Source(dot_data)
graph.format = 'png'
graph.render("burger_decision_tree")
graph # Display decision tree
